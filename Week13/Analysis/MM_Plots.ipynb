# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#read in the data
meta_d = np.loadtxt('../metad1_initmonitor/METADYN-1.ener', skiprows=1)

#plot the data
plt.plot(meta_d[:,1], meta_d[:,4], label='NVT')
plt.title('Potential Energy vs Time (NVT)')
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (kJ/mol)')
plt.legend()

# %%
#read in the data
cov_r_t = np.loadtxt('../metad1_initmonitor/METADYN-COLVAR.metadynLog')

# %%
#plot the data
plt.plot(cov_r_t[:,0], cov_r_t[:,1])
plt.title('Reaction Coordinate vs Time')
plt.xlabel('Time (fs)')
plt.ylabel('Reaction Coordinate (a.u)')
# Out:
# Text(0, 0.5, 'Reaction Coordinate (a.u)')
